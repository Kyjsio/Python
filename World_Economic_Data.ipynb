# %% [markdown]
# # World Economic Data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Preparing data

# %% [markdown]
# ### Check all the files

# %%
source_folder  = 'date'
print(os.listdir(source_folder))
# Out:
# ['corruption.csv', 'cost_of_living.csv', 'richest_countries.csv', 'tourism.csv', 'unemployment.csv']

# %% [markdown]
# ### Download every file and check how data looks like

# %%
df_corr = pd.read_csv("date/corruption.csv")
print(df_corr.info())
df_corr.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           110 non-null    object
#  1   annual_income     110 non-null    int64
#  2   corruption_index  110 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 2.7+ KB
# None
#        country  annual_income  corruption_index
# 0      Denmark          68110                12
# 1      Finland          53660                12
# 2  New Zealand          45340                12
# 3       Norway          84090                15
# 4    Singapore          64010                15

# %%
df_cost= pd.read_csv("date/cost_of_living.csv")
print(df_cost.info())
df_cost.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 107 non-null    object
#  1   cost_index              107 non-null    float64
#  2   monthly_income          107 non-null    int64
#  3   purchasing_power_index  107 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.5+ KB
# None
#           country  cost_index  monthly_income  purchasing_power_index
# 0         Bermuda       157.6            9712                   105.0
# 1     Switzerland       142.4            7530                    90.1
# 2  Cayman Islands       137.9            5281                    65.2
# 3          Israel       130.2            4130                    54.1
# 4         Iceland       128.0            5368                    71.5

# %%
df_richest= pd.read_csv("date/richest_countries.csv")
print(df_richest.info())
df_richest.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         50 non-null     object
#  1   gdp_per_capita  50 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 932.0+ bytes
# None
#       country  gdp_per_capita
# 0  Luxembourg          134754
# 1   Singapore          116486
# 2     Ireland          106456
# 3       Qatar           93521
# 4     Bermuda           85192

# %%
df_tourism= pd.read_csv("date/tourism.csv")
print(df_tourism.info())
df_tourism.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               41 non-null     object
#  1   tourists_in_millions  41 non-null     float64
#  2   receipts_in_billions  41 non-null     float64
#  3   receipts_per_tourist  41 non-null     int64
#  4   percentage_of_gdp     41 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.7+ KB
# None
#          country  tourists_in_millions  receipts_in_billions  \
# 0         France                 117.1                 35.96
# 1         Mexico                  51.1                 11.45
# 2  United States                  45.0                 84.21
# 3          Italy                  38.4                 20.46
# 4        Hungary                  31.6                  4.22
#
#    receipts_per_tourist  percentage_of_gdp
# 0                   307                1.2
# 1                   224                0.9
# 2                  1870                0.4
# 3                   533                1.0
# 4                   133                2.3

# %%
df_unemployment= pd.read_csv("date/unemployment.csv")
print(df_unemployment.info())
df_unemployment.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            64 non-null     object
#  1   unemployment_rate  64 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ KB
# None
#             country  unemployment_rate
# 0  Marshall Islands               36.0
# 1      South Africa               33.6
# 2          Kiribati               30.6
# 3            Kosovo               30.5
# 4    American Samoa               29.8

# %%
### Check

# %%
df_unemployment.isna().sum()
# Out:
# country              0
# unemployment_rate    0
# dtype: int64

# %%
df_cost.isna().sum()
# Out:
# country                   0
# cost_index                0
# monthly_income            0
# purchasing_power_index    0
# dtype: int64

# %%
df_corr.isna().sum()
# Out:
# country             0
# annual_income       0
# corruption_index    0
# dtype: int64

# %%
df_richest.isna().sum()
# Out:
# country           0
# gdp_per_capita    0
# dtype: int64

# %%
df_tourism.isna().sum()
# Out:
# country                 0
# tourists_in_millions    0
# receipts_in_billions    0
# receipts_per_tourist    0
# percentage_of_gdp       0
# dtype: int64

# %% [markdown]
# # At the start we look at each table separately
# ## Unemployment

# %%
len(df_unemployment['country'].unique())
# Out:
# 64

# %%
len(df_unemployment['country'])
# Out:
# 64

# %%
df_unemployment.describe()
# Out:
#        unemployment_rate
# count          64.000000
# mean            7.823437
# std             8.806685
# min             0.100000
# 25%             2.700000
# 50%             5.000000
# 75%             8.250000
# max            36.000000

# %%
T_unemployment=df_unemployment.sort_values("unemployment_rate" , ascending=False)[0:10:1]

# %%
T_unemployment
# Out:
#             country  unemployment_rate
# 0  Marshall Islands               36.0
# 1      South Africa               33.6
# 2          Kiribati               30.6
# 3            Kosovo               30.5
# 4    American Samoa               29.8
# 5          Djibouti               28.4
# 6          Eswatini               25.8
# 7            Greece               14.8
# 8             Spain               14.7
# 9            Brazil               14.4

# %%
unemployment_mean=df_unemployment['unemployment_rate'].mean()
unemployment_mean
# Out:
# 7.8234375

# %%
len(df_unemployment[df_unemployment['unemployment_rate']<unemployment_mean])
# Out:
# 47

# %%
plt.figure(figsize=(14, 8))
plt.bar(btm_unemployment['country'], btm_unemployment['unemployment_rate'], color='skyblue')
plt.ylabel('Unemployment Rate')
plt.xlabel('Country')
plt.title('Countries with Unemployment Rates Above Mean')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Tourism

# %%
print(df_tourism.info())
df_tourism.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               41 non-null     object
#  1   tourists_in_millions  41 non-null     float64
#  2   receipts_in_billions  41 non-null     float64
#  3   receipts_per_tourist  41 non-null     int64
#  4   percentage_of_gdp     41 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.7+ KB
# None
#          country  tourists_in_millions  receipts_in_billions  \
# 0         France                 117.1                 35.96
# 1         Mexico                  51.1                 11.45
# 2  United States                  45.0                 84.21
# 3          Italy                  38.4                 20.46
# 4        Hungary                  31.6                  4.22
#
#    receipts_per_tourist  percentage_of_gdp
# 0                   307                1.2
# 1                   224                0.9
# 2                  1870                0.4
# 3                   533                1.0
# 4                   133                2.3

# %%
df_tourism.shape
# Out:
# (41, 5)

# %%
len(df_tourism['country'].unique())
# Out:
# 41

# %%
t10_gdp_tourists = df_tourism.sort_values('percentage_of_gdp', ascending=False)[0:10]
plt.figure(figsize=(14,8))
plt.bar(t10_gdp_tourists['country'], t10_gdp_tourists['percentage_of_gdp'],color='skyblue')
plt.xticks(rotation=90)
plt.ylabel('GDP per Capita')
plt.xlabel('Country')
plt.show()

# %%
tourists_grad = df_tourism.sort_values(by=['tourists_in_millions','receipts_in_billions'], ascending=False).reset_index(drop=True)[:15]

# %%
tourists_grad.style.background_gradient()
# Out:
# <style type="text/css">
# #T_c463b_row0_col1, #T_c463b_row2_col2, #T_c463b_row8_col3, #T_c463b_row14_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c463b_row0_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_c463b_row0_col3, #T_c463b_row6_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c463b_row0_col4, #T_c463b_row1_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_c463b_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_c463b_row1_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_c463b_row1_col4, #T_c463b_row11_col1, #T_c463b_row12_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c463b_row2_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_c463b_row2_col3 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_c463b_row2_col4, #T_c463b_row9_col2, #T_c463b_row9_col3, #T_c463b_row13_col4, #T_c463b_row14_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c463b_row3_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_c463b_row3_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_c463b_row3_col3, #T_c463b_row14_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_c463b_row3_col4, #T_c463b_row10_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c463b_row4_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_c463b_row4_col2, #T_c463b_row5_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_c463b_row4_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c463b_row4_col4, #T_c463b_row11_col2 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_c463b_row5_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_c463b_row5_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_c463b_row5_col4 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_c463b_row6_col1, #T_c463b_row7_col4 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_c463b_row6_col2 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_c463b_row6_col3 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_c463b_row7_col1, #T_c463b_row11_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c463b_row7_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_c463b_row7_col3 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_c463b_row8_col1, #T_c463b_row13_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_c463b_row8_col2 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_c463b_row8_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c463b_row9_col1, #T_c463b_row12_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_c463b_row9_col4 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_c463b_row10_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_c463b_row10_col3 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_c463b_row10_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_c463b_row11_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_c463b_row12_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_c463b_row12_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_c463b_row13_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c463b_row13_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_c463b_row14_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# </style>
# <table id="T_c463b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c463b_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_c463b_level0_col1" class="col_heading level0 col1" >tourists_in_millions</th>
#       <th id="T_c463b_level0_col2" class="col_heading level0 col2" >receipts_in_billions</th>
#       <th id="T_c463b_level0_col3" class="col_heading level0 col3" >receipts_per_tourist</th>
#       <th id="T_c463b_level0_col4" class="col_heading level0 col4" >percentage_of_gdp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c463b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c463b_row0_col0" class="data row0 col0" >France</td>
#       <td id="T_c463b_row0_col1" class="data row0 col1" >117.100000</td>
#       <td id="T_c463b_row0_col2" class="data row0 col2" >35.960000</td>
#       <td id="T_c463b_row0_col3" class="data row0 col3" >307</td>
#       <td id="T_c463b_row0_col4" class="data row0 col4" >1.200000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c463b_row1_col0" class="data row1 col0" >Mexico</td>
#       <td id="T_c463b_row1_col1" class="data row1 col1" >51.100000</td>
#       <td id="T_c463b_row1_col2" class="data row1 col2" >11.450000</td>
#       <td id="T_c463b_row1_col3" class="data row1 col3" >224</td>
#       <td id="T_c463b_row1_col4" class="data row1 col4" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c463b_row2_col0" class="data row2 col0" >United States</td>
#       <td id="T_c463b_row2_col1" class="data row2 col1" >45.000000</td>
#       <td id="T_c463b_row2_col2" class="data row2 col2" >84.210000</td>
#       <td id="T_c463b_row2_col3" class="data row2 col3" >1870</td>
#       <td id="T_c463b_row2_col4" class="data row2 col4" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c463b_row3_col0" class="data row3 col0" >Italy</td>
#       <td id="T_c463b_row3_col1" class="data row3 col1" >38.400000</td>
#       <td id="T_c463b_row3_col2" class="data row3 col2" >20.460000</td>
#       <td id="T_c463b_row3_col3" class="data row3 col3" >533</td>
#       <td id="T_c463b_row3_col4" class="data row3 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c463b_row4_col0" class="data row4 col0" >Hungary</td>
#       <td id="T_c463b_row4_col1" class="data row4 col1" >31.600000</td>
#       <td id="T_c463b_row4_col2" class="data row4 col2" >4.220000</td>
#       <td id="T_c463b_row4_col3" class="data row4 col3" >133</td>
#       <td id="T_c463b_row4_col4" class="data row4 col4" >2.300000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c463b_row5_col0" class="data row5 col0" >Croatia</td>
#       <td id="T_c463b_row5_col1" class="data row5 col1" >21.600000</td>
#       <td id="T_c463b_row5_col2" class="data row5 col2" >5.630000</td>
#       <td id="T_c463b_row5_col3" class="data row5 col3" >261</td>
#       <td id="T_c463b_row5_col4" class="data row5 col4" >8.300000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c463b_row6_col0" class="data row6 col0" >Turkey</td>
#       <td id="T_c463b_row6_col1" class="data row6 col1" >16.000000</td>
#       <td id="T_c463b_row6_col2" class="data row6 col2" >13.770000</td>
#       <td id="T_c463b_row6_col3" class="data row6 col3" >862</td>
#       <td id="T_c463b_row6_col4" class="data row6 col4" >1.700000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c463b_row7_col0" class="data row7 col0" >Austria</td>
#       <td id="T_c463b_row7_col1" class="data row7 col1" >15.100000</td>
#       <td id="T_c463b_row7_col2" class="data row7 col2" >15.360000</td>
#       <td id="T_c463b_row7_col3" class="data row7 col3" >1018</td>
#       <td id="T_c463b_row7_col4" class="data row7 col4" >3.200000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c463b_row8_col0" class="data row8 col0" >Germany</td>
#       <td id="T_c463b_row8_col1" class="data row8 col1" >12.400000</td>
#       <td id="T_c463b_row8_col2" class="data row8 col2" >58.370000</td>
#       <td id="T_c463b_row8_col3" class="data row8 col3" >4689</td>
#       <td id="T_c463b_row8_col4" class="data row8 col4" >1.400000</td>
#     </tr>
#     <tr>
#       <th id="T_c463b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c463b_row9_col0" cla

# %% [markdown]
# The data analysis shows France,Mexico and United States are the most frequently coutries ,but France with 117millions tourists have less receipts than Germant with almost x10 less tourists or x2 more tourists than USA ,but also x2 less receipts.

# %% [markdown]
# ## Richest Countries

# %%
t10_richest=df_richest.head(10)
t10_richest
# Out:
#          country  gdp_per_capita
# 0     Luxembourg          134754
# 1      Singapore          116486
# 2        Ireland          106456
# 3          Qatar           93521
# 4        Bermuda           85192
# 5         Norway           79201
# 6    Switzerland           77324
# 7          Macao           73802
# 8  United States           69288
# 9         Brunei           66620

# %%
plt.figure(figsize=(14,8))
plt.bar(t10_richest['country'],t10_richest['gdp_per_capita'],color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('G')
# Out:
# Text(0.5, 0, 'Country')

# %% [markdown]
# ## Corruption

# %%
t15_corr=df_corr.sort_values('annual_income',ascending=False).head(15)

# %%
fig, corr=plt.subplots(figsize=(16, 6))

corr.set_ylabel('Annual Income', color='skyblue')
corr.bar(t15_corr['country'], t15_corr['annual_income'],color='skyblue')
corr.tick_params(axis='y', labelcolor='skyblue')
corr.set_xticklabels(t15_corr['country'],rotation=90)
corr.set_xlabel('Country')
corr.set_title('Richest country vs corruption')
inc=corr.twinx()

inc.set_ylabel('Corruption Index', color='blue')
inc.plot(t15_corr['country'], t15_corr['corruption_index'],color='blue',marker="o")
inc.tick_params(axis='y', labelcolor='blue')
plt.show()

# %%
df_corr_v2=df_corr.copy()
df_corr_v2.loc[df_corr_v2['corruption_index'].between(0, 20, 'right'), 'corruption_index_group'] = '0-20'
df_corr_v2.loc[df_corr_v2['corruption_index'].between(20, 40, 'right'), 'corruption_index_group'] = '20-40'
df_corr_v2.loc[df_corr_v2['corruption_index'].between(40, 60, 'right'), 'corruption_index_group'] = '40-60'
df_corr_v2.loc[df_corr_v2['corruption_index'].between(60, 80, 'right'), 'corruption_index_group'] = '60-80'
df_corr_v2.loc[df_corr_v2['corruption_index'].between(80, 100, 'right'), 'corruption_index_group'] = '80-100'

sns.boxplot(data =df_corr_v2, x = 'corruption_index_group', y = 'annual_income')
plt.grid(True)
plt.xlabel('Corruption index')
plt.ylabel('Annual income')
plt.title('Group of Corruption')
# Out:
# Text(0.5, 1.0, 'Group of Corruption')

# %% [markdown]
# The data analysis shows the country with the highest annual income have corruption index between 0-20 and median is a bit above a 60000 annual income.Interestigly looks group 80-100 ,where median income is close to 0 and this same time few countries is richest than some countries in group 60-80 with less corruption.

# %% [markdown]
# ## Cost_of_living

# %%
df_cost.head(10)
# Out:
#                     country  cost_index  monthly_income  \
# 0                   Bermuda       157.6            9712
# 1               Switzerland       142.4            7530
# 2            Cayman Islands       137.9            5281
# 3                    Israel       130.2            4130
# 4                   Iceland       128.0            5368
# 5             New Caledonia       125.8            1101
# 6  Turks and Caicos Islands       124.6            1967
# 7                    Norway       124.6            7008
# 8                  Barbados       121.5            1393
# 9                   Denmark       119.9            5676
#
#    purchasing_power_index
# 0                   105.0
# 1                    90.1
# 2                    65.2
# 3                    54.1
# 4                    71.5
# 5                    14.9
# 6                    26.9
# 7                    95.9
# 8                    19.5
# 9                    80.6

# %%
df_cost_inc=df_cost.sort_values('monthly_income',ascending=False)[:30]

fig, pl1 = plt.subplots(figsize=(16, 6))

pl1.set_ylabel('Monthly Income', color='skyblue')
pl1.bar(df_cost_inc['country'], df_cost_inc['monthly_income'],color='skyblue')
pl1.tick_params(axis='y', labelcolor='skyblue')
pl1.set_title('Monthly income vs Cost index')
pl1.set_xticklabels(df_cost_inc['country'], rotation=90)
pl1.set_xlabel('Country')
pl2 = pl1.twinx() 

pl2.set_ylabel('Cost Index', color='blue')
pl2.plot(df_cost_inc['country'], df_cost_inc['cost_index'], color='blue', marker='o')
pl2.tick_params(axis='y', labelcolor='blue')

plt.show()

# %% [markdown]
# ## Combined data

# %%
all_df= df_corr.merge(df_unemployment, on = 'country', how = 'inner', sort = True).merge(df_richest, on = 'country', how = 'inner', sort = True).merge(df_cost, on = 'country', how = 'inner', sort = True)
all_df = all_df.sort_values(by =['annual_income','corruption_index','unemployment_rate','gdp_per_capita','purchasing_power_index'], ascending=False).reset_index(drop=True)
all_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_3d958_row0_col1, #T_3d958_row0_col5, #T_3d958_row0_col6, #T_3d958_row2_col4, #T_3d958_row6_col7, #T_3d958_row21_col3, #T_3d958_row24_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3d958_row0_col2, #T_3d958_row22_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_3d958_row0_col3, #T_3d958_row11_col3 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_3d958_row0_col4 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_3d958_row0_col7, #T_3d958_row16_col5 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_3d958_row1_col1, #T_3d958_row1_col6 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_3d958_row1_col2, #T_3d958_row6_col2, #T_3d958_row7_col2, #T_3d958_row23_col1, #T_3d958_row23_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_3d958_row1_col3, #T_3d958_row13_col7, #T_3d958_row17_col1, #T_3d958_row17_col6, #T_3d958_row24_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_3d958_row1_col4 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_3d958_row1_col5 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_3d958_row1_col7 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_3d958_row2_col1, #T_3d958_row2_col6 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_3d958_row2_col2, #T_3d958_row16_col4, #T_3d958_row23_col5 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_3d958_row2_col3, #T_3d958_row23_col3 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_3d958_row2_col5, #T_3d958_row3_col4, #T_3d958_row23_col2 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_3d958_row2_col7 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_3d958_row3_col1, #T_3d958_row3_col6 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_3d958_row3_col2, #T_3d958_row13_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_3d958_row3_col3 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_3d958_row3_col5, #T_3d958_row5_col5 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_3d958_row3_col7, #T_3d958_row8_col4 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_3d958_row4_col1, #T_3d958_row4_col6 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_3d958_row4_col2, #T_3d958_row4_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_3d958_row4_col4, #T_3d958_row21_col5 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_3d958_row4_col5, #T_3d958_row7_col1, #T_3d958_row7_col6 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_3d958_row4_col7 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_3d958_row5_col1, #T_3d958_row5_col6 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_3d958_row5_col2, #T_3d958_row8_col3, #T_3d958_row21_col7, #T_3d958_row25_col1, #T_3d958_row25_col4, #T_3d958_row25_col5, #T_3d958_row25_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3d958_row5_col3, #T_3d958_row18_col1, #T_3d958_row18_col6 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_3d958_row5_col4 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_3d958_row5_col7, #T_3d958_row12_col6 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_3d958_row6_col1, #T_3d958_row6_col6 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_3d958_row6_col3, #T_3d958_row18_col7 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_3d958_row6_col4 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_3d958_row6_col5 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_3d958_row7_col3 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_3d958_row7_col4 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_3d958_row7_col5 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_3d958_row7_col7 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_3d958_row8_col1, #T_3d958_row8_col6 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_3d958_row8_col2, #T_3d958_row15_col1, #T_3d958_row15_col6 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_3d958_row8_col5, #T_3d958_row11_col4 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_3d958_row8_col7 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_3d958_row9_col1, #T_3d958_row9_col6 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_3d958_row9_col2, #T_3d958_row10_col3, #T_3d958_row16_col2, #T_3d958_row16_col7 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_3d958_row9_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_3d958_row9_col4 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_3d958_row9_col5 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_3d958_row9_col7 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_3d958_row10_col1, #T_3d958_row10_col6 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_3d958_row10_col2, #T_3d958_row19_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_3d958_row10_col4, #T_3d958_row15_col7 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_3d958_row10_col5 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_3d958_row10_col7, #T_3d958_row12_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_3d958_row11_col1, #T_3d958_row11_col6 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_3d958_row11_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_3d958_row11_col5 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_3d958_row11_col7 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_3d958_row12_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_3d958_row12_col3, #T_3d958_row18_col3 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_3d958_row12_col4 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_3d958_row12_col5, #T_3d958_row15_col3 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_3d958_row12_col7, #T_3d958_row18_col5 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_3d958_row13_col1, #T_3d958_row13_col6, #T_3d958_row17_col5 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_3d958_row13_col3 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_3d958_row13_col4, #T_3d958_row22_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_3d958_row13_col5 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_3d958_row14_col1, #T_3d958_row14_col6 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_3d958_row14_col2 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_3d958_row14_col3 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_3d958_row14_col4 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_3d958_row14_col5 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_3d958_row14_col7 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_3d958_row15_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_3d958_row15_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_3d958_row15_col5 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_3d958_row16_col1, #T_3d958_row16_col6 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_3d958_row16_col3 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_3d958_row17_col2, #T_3d958_row22_col2 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_3d958_row17_col3 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_3d958_row17_col4, #T_3d958_row19_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_3d958_row17_col7, #T_3d958_row19_col1, #T_3d958_row19_col6 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_3d958_row18_col2 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_3d958_row18_col4 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_3d958_row19_col2 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_3d958_row19_col3 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_3d958_row19_col5 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_3d958_row20_col1, #T_3d958_row20_col6, #T_3d958_row22_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_3d958_row20_col2 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_3d958_row20_col3 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_3d958_row20_col4 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_3d958_row20_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T
